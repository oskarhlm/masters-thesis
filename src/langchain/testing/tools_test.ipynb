# %%
from langchain import hub
from langchain_openai import ChatOpenAI
from langchain.agents import create_openai_tools_agent
from langchain_experimental.tools.python.tool import PythonAstREPLTool
from langgraph.prebuilt import create_agent_executor
from dotenv import load_dotenv

load_dotenv('../../.env')

prompt = hub.pull("hwchase17/openai-tools-agent")
tools = [PythonAstREPLTool()]

llm = ChatOpenAI(model="gpt-3.5-turbo-1106")

agent_runnable = create_openai_tools_agent(llm, tools, prompt)

app = create_agent_executor(agent_runnable, tools)

# %%
inputs = {"input": "do some fibonacci", "chat_history": []}
for s in app.stream(inputs):
    print(list(s.values())[0])
    print("----")
# Out:
# {'agent_outcome': [OpenAIToolAgentAction(tool='python_repl_ast', tool_input={'query': 'def fibonacci(n):\n    a, b = 0, 1\n    for _ in range(n):\n        a, b = b, a + b\n    return a\n\nfibonacci(10)'}, log="\nInvoking: `python_repl_ast` with `{'query': 'def fibonacci(n):\\n    a, b = 0, 1\\n    for _ in range(n):\\n        a, b = b, a + b\\n    return a\\n\\nfibonacci(10)'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_71NYtRc0RE8mGDaBeDkbUQBP', 'function': {'arguments': '{"query":"def fibonacci(n):\\n    a, b = 0, 1\\n    for _ in range(n):\\n        a, b = b, a + b\\n    return a\\n\\nfibonacci(10)"}', 'name': 'python_repl_ast'}, 'type': 'function'}]})], tool_call_id='call_71NYtRc0RE8mGDaBeDkbUQBP')]}
# ----
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 2
#       1 inputs = {"input": "do some fibonacci", "chat_history": []}
# ----> 2 for s in app.stream(inputs):
#       3     print(list(s.values())[0])
#       4     print("----")
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langgraph/pregel/__init__.py:615, in Pregel.transform(self, input, config, output_keys, input_keys, **kwargs)
#     606 def transform(
#     607     self,
#     608     input: Iterator[Union[dict[str, Any], Any]],
#    (...)
#     613     **kwargs: Any,
#     614 ) -> Iterator[Union[dict[str, Any], Any]]:
# --> 615     for chunk in self._transform_stream_with_config(
#     616         input,
#     617         self._transform,
#     618         config,
#     619         output_keys=output_keys,
#     620         input_keys=input_keys,
#     621         **kwargs,
#     622     ):
#     623         yield chunk
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:1494, in Runnable._transform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    1492 try:
#    1493     while True:
# -> 1494         chunk: Output = context.run(next, iterator)  # type: ignore
#    1495         yield chunk
#    1496         if final_output_supported:
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langgraph/pregel/__init__.py:355, in Pregel._transform(self, input, run_manager, config, input_keys, output_keys, interrupt)
#     348 done, inflight = concurrent.futures.wait(
#     349     futures,
#     350     return_when=concurrent.futures.FIRST_EXCEPTION,
#     351     timeout=self.step_timeout,
#     352 )
#     354 # interrupt on failure or timeout
# --> 355 _interrupt_or_proceed(done, inflight, step)
#     357 # apply writes to channels
#     358 _apply_writes(
#     359     checkpoint, channels, pending_writes, config, step + 1
#     360 )
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langgraph/pregel/__init__.py:698, in _interrupt_or_proceed(done, inflight, step)
#     696             inflight.pop().cancel()
#     697         # raise the exception
# --> 698         raise exc
#     699         # TODO this is where retry of an entire step would happen
#     701 if inflight:
#     702     # if we got here means we timed out
#
# File /usr/lib/python3.11/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:4060, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    4054 def invoke(
#    4055     self,
#    4056     input: Input,
#    4057     config: Optional[RunnableConfig] = None,
#    4058     **kwargs: Optional[Any],
#    4059 ) -> Output:
# -> 4060     return self.bound.invoke(
#    4061         input,
#    4062         self._merge_configs(config),
#    4063         **{**self.kwargs, **kwargs},
#    4064     )
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:2056, in RunnableSequence.invoke(self, input, config)
#    2054 try:
#    2055     for i, step in enumerate(self.steps):
# -> 2056         input = step.invoke(
#    2057             input,
#    2058             # mark each step as a child run
#    2059             patch_config(
#    2060                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    2061             ),
#    2062         )
#    2063 # finish the root run
#    2064 except BaseException as e:
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:3504, in RunnableLambda.invoke(self, input, config, **kwargs)
#    3502 """Invoke this runnable synchronously."""
#    3503 if hasattr(self, "func"):
# -> 3504     return self._call_with_config(
#    3505         self._invoke,
#    3506         input,
#    3507         self._config(config, self.func),
#    3508         **kwargs,
#    3509     )
#    3510 else:
#    3511     raise TypeError(
#    3512         "Cannot invoke a coroutine function synchronously."
#    3513         "Use `ainvoke` instead."
#    3514     )
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:1243, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#    1239     context = copy_context()
#    1240     context.run(var_child_runnable_config.set, child_config)
#    1241     output = cast(
#    1242         Output,
# -> 1243         context.run(
#    1244             call_func_with_variable_args,
#    1245             func,  # type: ignore[arg-type]
#    1246             input,  # type: ignore[arg-type]
#    1247             config,
#    1248             run_manager,
#    1249             **kwargs,
#    1250         ),
#    1251     )
#    1252 except BaseException as e:
#    1253     run_manager.on_chain_error(e)
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/config.py:326, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     324 if run_manager is not None and accepts_run_manager(func):
#     325     kwargs["run_manager"] = run_manager
# --> 326 return func(input, **kwargs)
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:3378, in RunnableLambda._invoke(self, input, run_manager, config, **kwargs)
#    3376                 output = chunk
#    3377 else:
# -> 3378     output = call_func_with_variable_args(
#    3379         self.func, input, config, run_manager, **kwargs
#    3380     )
#    3381 # If the output is a runnable, invoke it
#    3382 if isinstance(output, Runnable):
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/config.py:326, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     324 if run_manager is not None and accepts_run_manager(func):
#     325     kwargs["run_manager"] = run_manager
# --> 326 return func(input, **kwargs)
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langgraph/prebuilt/agent_executor.py:75, in create_agent_executor.<locals>.execute_tools(data)
#      72 def execute_tools(data):
#      73     # Get the most recent agent_outcome - this is the key added in the `agent` above
#      74     agent_action = data["agent_outcome"]
# ---> 75     output = tool_executor.invoke(agent_action)
#      76     return {"intermediate_steps": [(agent_action, str(output))]}
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:4060, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    4054 def invoke(
#    4055     self,
#    4056     input: Input,
#    4057     config: Optional[RunnableConfig] = None,
#    4058     **kwargs: Optional[Any],
#    4059 ) -> Output:
# -> 4060     return self.bound.invoke(
#    4061         input,
#    4062         self._merge_configs(config),
#    4063         **{**self.kwargs, **kwargs},
#    4064     )
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:3504, in RunnableLambda.invoke(self, input, config, **kwargs)
#    3502 """Invoke this runnable synchronously."""
#    3503 if hasattr(self, "func"):
# -> 3504     return self._call_with_config(
#    3505         self._invoke,
#    3506         input,
#    3507         self._config(config, self.func),
#    3508         **kwargs,
#    3509     )
#    3510 else:
#    3511     raise TypeError(
#    3512         "Cannot invoke a coroutine function synchronously."
#    3513         "Use `ainvoke` instead."
#    3514     )
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:1243, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#    1239     context = copy_context()
#    1240     context.run(var_child_runnable_config.set, child_config)
#    1241     output = cast(
#    1242         Output,
# -> 1243         context.run(
#    1244             call_func_with_variable_args,
#    1245             func,  # type: ignore[arg-type]
#    1246             input,  # type: ignore[arg-type]
#    1247             config,
#    1248             run_manager,
#    1249             **kwargs,
#    1250         ),
#    1251     )
#    1252 except BaseException as e:
#    1253     run_manager.on_chain_error(e)
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/config.py:326, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     324 if run_manager is not None and accepts_run_manager(func):
#     325     kwargs["run_manager"] = run_manager
# --> 326 return func(input, **kwargs)
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:3378, in RunnableLambda._invoke(self, input, run_manager, config, **kwargs)
#    3376                 output = chunk
#    3377 else:
# -> 3378     output = call_func_with_variable_args(
#    3379         self.func, input, config, run_manager, **kwargs
#    3380     )
#    3381 # If the output is a runnable, invoke it
#    3382 if isinstance(output, Runnable):
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/config.py:326, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     324 if run_manager is not None and accepts_run_manager(func):
#     325     kwargs["run_manager"] = run_manager
# --> 326 return func(input, **kwargs)
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langgraph/prebuilt/tool_executor.py:53, in ToolExecutor._execute(self, tool_invocation, config)
#      50 def _execute(
#      51     self, tool_invocation: ToolInvocationInterface, *, config: RunnableConfig
#      52 ) -> Any:
# ---> 53     if tool_invocation.tool not in self.tool_map:
#      54         return self.invalid_tool_msg_template.format(
#      55             requested_tool_name=tool_invocation.tool,
#      56             available_tool_names_str=", ".join([t.name for t in self.tools]),
#      57         )
#      58     else:
#
# AttributeError: 'list' object has no attribute 'tool'
