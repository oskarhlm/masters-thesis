# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_openai import ChatOpenAI
from langchain.chains.openai_functions import create_structured_output_runnable
from enum import Enum
from langchain.output_parsers.openai_functions import JsonOutputFunctionsParser
from typing import Annotated, Any, Dict, List, Optional, Sequence, TypedDict, Union, Literal
from langchain_core.messages import BaseMessage, HumanMessage
import operator
from langchain.pydantic_v1 import BaseModel

# class Next(Enum):
#     ANALYSIS = 'spatial_analysis_worker'
#     MAP = 'client_map_worker'


class Worker(Enum):
    CODE = 'code_worker'
    SUMMARY = 'summary_worker'

    @classmethod
    def get_description(cls, worker: 'Worker'):    
        return {
            Worker.CODE.value: 'A coding worker/agent that can produce and execute Python code',
            Worker.SUMMARY.value: 'A summary writing worker/agent that can produce summaries of human-AI conversations'
        }.get(worker.value)

class AgentState(TypedDict):
    initial_query: str
    messages: Annotated[Sequence[BaseMessage], operator.add]
    next: Worker


def create_agent_supervisor(members: Sequence[Worker]):
    system_prompt = (
        "You are a supervisor tasked with managing a conversation between the"
        " following workers:\n{members}\n\n Given the following user request,"
        " respond with the worker to act next. Each worker will perform a"
        " task and respond with their results and status. When finished,"
        " respond with FINISH."
    )

    options = ["FINISH"] + [m.value for m in members]
    print(options)

    function_def = {
        "name": "route",
        "description": "Select the next role.",
        "parameters": {
            "title": "routeSchema",
            "type": "object",
            "properties": {
                "next": {
                    "title": "Next",
                    "anyOf": [
                        {"enum": options},
                    ],
                },
            },
            "required": ["next"],
        },
    }

    bullet_point_list = "\n".join(f"{i+1}) {member.value} - {Worker.get_description(member)}"
                                  for i, member in enumerate(members))

    prompt = ChatPromptTemplate.from_messages(
        [
            ("system", system_prompt),
            MessagesPlaceholder(variable_name="messages"),
            (
                "system",
                ( 
                    "Given the conversation above, who should act next, if any?"
                    ' Return "FINISH" if the initial human query ("{initial_query}") has been answered?\n\n'
                    "Select one of: {options}\n\n"
                    "Give you answer as a dict: {'next': <selected_option>}"
                )
            )
        ]
    ).partial(options=options, members=bullet_point_list)

    llm = ChatOpenAI(model="gpt-3.5-turbo-0125", streaming=True)

    # return create_structured_output_runnable(
    #     {
    #         'code_worker': 'string',
    #         'summary_worker': 'string',
    #         'FINISH': 'string',
    #     }, 
    #     llm, 
    #     prompt
    # )
    return (
        prompt
        | llm.bind_functions(functions=[function_def], function_call="route")
        # | llm
        | JsonOutputFunctionsParser()
    )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
#       2 from langchain_openai import ChatOpenAI
# ----> 3 from langchain.chains.openai_functions import create_structured_output_runnable
#       4 from enum import Enum
#       5 from langchain.output_parsers.openai_functions import JsonOutputFunctionsParser
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain/chains/__init__.py:37
#      35 from langchain.chains.flare.base import FlareChain
#      36 from langchain.chains.graph_qa.arangodb import ArangoGraphQAChain
# ---> 37 from langchain.chains.graph_qa.base import GraphQAChain
#      38 from langchain.chains.graph_qa.cypher import GraphCypherQAChain
#      39 from langchain.chains.graph_qa.falkordb import FalkorDBQAChain
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain/chains/graph_qa/base.py:11
#       8 from langchain_core.prompts import BasePromptTemplate
#       9 from langchain_core.pydantic_v1 import Field
# ---> 11 from langchain.callbacks.manager import CallbackManagerForChainRun
#      12 from langchain.chains.base import Chain
#      13 from langchain.chains.graph_qa.prompts import ENTITY_EXTRACTION_PROMPT, GRAPH_QA_PROMPT
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain/callbacks/__init__.py:17
#      12 from langchain_core._api import LangChainDeprecationWarning
#      13 from langchain_core.callbacks import (
#      14     StdOutCallbackHandler,
#      15     StreamingStdOutCallbackHandler,
#      16 )
# ---> 17 from langchain_core.tracers.context import (
#      18     collect_runs,
#      19     tracing_enabled,
#      20     tracing_v2_enabled,
#      21 )
#      22 from langchain_core.tracers.langchain import LangChainTracer
#      24 from langchain.callbacks.file import FileCallbackHandler
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/tracers/__init__.py:12
#       1 __all__ = [
#       2     "BaseTracer",
#       3     "EvaluatorCallbackHandler",
#    (...)
#       9     "LogStreamCallbackHandler",
#      10 ]
# ---> 12 from langchain_core.tracers.base import BaseTracer
#      13 from langchain_core.tracers.evaluation import EvaluatorCallbackHandler
#      14 from langchain_core.tracers.langchain import LangChainTracer
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:936, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1032, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1131, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
from langchain.agents import AgentExecutor, create_openai_tools_agent
from langchain_core.messages import HumanMessage
from langchain.tools import BaseTool
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser


def create_agent(llm: ChatOpenAI, tools: Sequence[BaseTool], system_prompt: str):
    prompt = ChatPromptTemplate.from_messages(
        [
            (
                "system",
                system_prompt,
            ),
            MessagesPlaceholder(variable_name="messages"),
            MessagesPlaceholder(variable_name="agent_scratchpad"),
        ]
    )

    if len(tools) == 0:
        return (
            ChatPromptTemplate.from_template(system_prompt)
            | llm
            | StrOutputParser()
        )

    agent = create_openai_tools_agent(llm, tools, prompt)
    executor = AgentExecutor(agent=agent, tools=tools)
    return executor


async def agent_node(state: AgentState, agent, name):
    result = await agent.ainvoke(state)
    # content = result["output"] if isinstance(result, dict) else result
    return {"messages": [HumanMessage(content=result['output'], name=name)]}

# %%
import functools
from langgraph.graph import StateGraph, END
from langchain_experimental.tools import PythonREPLTool

supervisor_chain = create_agent_supervisor([e for e in Worker])

llm = ChatOpenAI(model="gpt-3.5-turbo-0125", streaming=True)

summary_agent = create_agent(llm, [], "You are a summary agent. Write a summary of the conversation so far: {messages}")
summary_node = functools.partial(
    agent_node, agent=summary_agent, name="Summarizer")

code_agent = create_agent(
    llm,
    [PythonREPLTool()],
    "You are a coding agent.",
)
code_node = functools.partial(agent_node, agent=code_agent, name="Coder")

SUPERVISOR = 'supervisor'

workflow = StateGraph(AgentState)
workflow.add_node(Worker.SUMMARY.value, summary_node)
workflow.add_node(Worker.CODE.value, code_node)
workflow.add_node(SUPERVISOR, supervisor_chain)

# %%
for member in Worker:
    workflow.add_edge(member.value, SUPERVISOR)

conditional_map = {k.value: k.value for k in Worker}
conditional_map["FINISH"] = END
workflow.add_conditional_edges(
    SUPERVISOR, lambda x: x["next"], conditional_map)

    
workflow.set_entry_point(SUPERVISOR)

app = workflow.compile()

# %%
messages = [HumanMessage(content="What is 576 * 5 / 13?")]
async for event in app.astream_events(
    {
        'initial_query': messages[0].content,
        "messages": messages
    },
    {"recursion_limit": 100},
    version="v1"
):
    kind = event["event"]
    print(event)
    # if kind == "on_chat_model_stream":
    #     content = event["data"]["chunk"].content
    #     if content:
    #         # Empty content in the context of OpenAI means
    #         # that the model is asking for a tool to be invoked.
    #         # So we only print non-empty content
    #         print(content, end="|")
    # elif kind == "on_tool_start":
    #     print("--")
    #     print(
    #         f"Starting tool: {event['name']} with inputs: {event['data'].get('input')}"
    #     )
    # elif kind == "on_tool_end":
    #     print(f"Done tool: {event['name']}")
    #     print(f"Tool output was: {event['data'].get('output')}")
    #     print("--")
# Out:
# NotImplementedError in LogStreamCallbackHandler.on_chain_end callback: NotImplementedError("Trying to load an object that doesn't implement serialization: {'lc': 1, 'type': 'not_implemented', 'id': ['builtins', 'object'], 'repr': '<object object at 0x7f28d52265e0>'}")
# {'event': 'on_chain_start', 'run_id': '45c41d8c-73a6-4133-817e-bfedc58d7c1e', 'name': 'LangGraph', 'tags': [], 'metadata': {}, 'data': {'input': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')]}}}
# {'event': 'on_chain_start', 'name': '__start__', 'run_id': '4b773fa8-4a39-436e-a911-0bcccb226c59', 'tags': ['graph:step:0', 'langsmith:hidden'], 'metadata': {}, 'data': {}}
# {'event': 'on_chain_stream', 'name': '__start__', 'run_id': '4b773fa8-4a39-436e-a911-0bcccb226c59', 'tags': ['graph:step:0', 'langsmith:hidden'], 'metadata': {}, 'data': {'chunk': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')]}}}
# {'event': 'on_chain_end', 'name': '__start__', 'run_id': '4b773fa8-4a39-436e-a911-0bcccb226c59', 'tags': ['graph:step:0', 'langsmith:hidden'], 'metadata': {}, 'data': {'input': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')]}, 'output': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')]}}}
# {'event': 'on_chain_start', 'name': '__start__', 'run_id': '27221ef7-894f-4ef7-8956-8d7a16cb80d6', 'tags': ['graph:step:0', 'langsmith:hidden'], 'metadata': {}, 'data': {'input': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')]}}}
# {'event': 'on_chain_start', 'name': '__start__', 'run_id': 'e2961c3b-8969-44e8-b553-20b71aed7529', 'tags': ['graph:step:0', 'langsmith:hidden'], 'metadata': {}, 'data': {'input': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')]}}}
# {'event': 'on_chain_start', 'name': '__start__', 'run_id': 'c5ae7508-9b04-49c8-92dd-c2c28fd8f2b6', 'tags': ['graph:step:0', 'langsmith:hidden'], 'metadata': {}, 'data': {'input': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')]}}}
# {'event': 'on_chain_end', 'name': '__start__', 'run_id': '27221ef7-894f-4ef7-8956-8d7a16cb80d6', 'tags': ['graph:step:0', 'langsmith:hidden'], 'metadata': {}, 'data': {'input': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')]}, 'output': 'What is 576 * 5 / 13?'}}
# {'event': 'on_chain_end', 'name': '__start__', 'run_id': 'e2961c3b-8969-44e8-b553-20b71aed7529', 'tags': ['graph:step:0', 'langsmith:hidden'], 'metadata': {}, 'data': {'input': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')]}, 'output': [HumanMessage(content='What is 576 * 5 / 13?')]}}
# {'event': 'on_chain_start', 'name': '__start__:edges', 'run_id': 'e839b365-cc1c-4a3b-aa5b-0e860f0f3649', 'tags': ['graph:step:1', 'langsmith:hidden'], 'metadata': {}, 'data': {}}
# {'event': 'on_chain_start', 'name': "ChannelRead<['initial_query', 'messages', 'next']>", 'run_id': '53157210-35a2-4e09-8171-ba53933f6c8b', 'tags': ['seq:step:1', 'langsmith:hidden'], 'metadata': {}, 'data': {}}
# {'event': 'on_chain_stream', 'name': "ChannelRead<['initial_query', 'messages', 'next']>", 'run_id': '53157210-35a2-4e09-8171-ba53933f6c8b', 'tags': ['seq:step:1', 'langsmith:hidden'], 'metadata': {}, 'data': {'chunk': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')], 'next': None}}}
# {'event': 'on_chain_start', 'name': 'ChannelWrite<supervisor:inbox>', 'run_id': 'f9df10be-c8a7-4a9c-b4d0-c5b2d54e91ff', 'tags': ['seq:step:2', 'langsmith:hidden'], 'metadata': {}, 'data': {}}
# {'event': 'on_chain_stream', 'name': 'ChannelWrite<supervisor:inbox>', 'run_id': 'f9df10be-c8a7-4a9c-b4d0-c5b2d54e91ff', 'tags': ['seq:step:2', 'langsmith:hidden'], 'metadata': {}, 'data': {'chunk': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')], 'next': None}}}
# {'event': 'on_chain_stream', 'name': '__start__:edges', 'run_id': 'e839b365-cc1c-4a3b-aa5b-0e860f0f3649', 'tags': ['graph:step:1', 'langsmith:hidden'], 'metadata': {}, 'data': {'chunk': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')], 'next': None}}}
# {'event': 'on_chain_end', 'name': "ChannelRead<['initial_query', 'messages', 'next']>", 'run_id': '53157210-35a2-4e09-8171-ba53933f6c8b', 'tags': ['seq:step:1', 'langsmith:hidden'], 'metadata': {}, 'data': {'input': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')]}, 'output': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')], 'next': None}}}
# {'event': 'on_chain_end', 'name': 'ChannelWrite<supervisor:inbox>', 'run_id': 'f9df10be-c8a7-4a9c-b4d0-c5b2d54e91ff', 'tags': ['seq:step:2', 'langsmith:hidden'], 'metadata': {}, 'data': {'input': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')], 'next': None}, 'output': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')], 'next': None}}}
# {'event': 'on_chain_end', 'name': '__start__:edges', 'run_id': 'e839b365-cc1c-4a3b-aa5b-0e860f0f3649', 'tags': ['graph:step:1', 'langsmith:hidden'], 'metadata': {}, 'data': {'input': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')]}, 'output': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')], 'next': None}}}
# {'event': 'on_chain_start', 'name': 'supervisor', 'run_id': 'ac964d7c-f88e-4b49-8b43-dfda62cdf77b', 'tags': ['graph:step:2'], 'metadata': {}, 'data': {}}
# {'event': 'on_chain_start', 'name': 'RunnableLambda', 'run_id': 'da7d0f85-df0e-425f-a2c4-b8952f42b7ac', 'tags': ['seq:step:1'], 'metadata': {}, 'data': {}}
# {'event': 'on_chain_stream', 'name': 'RunnableLambda', 'run_id': 'da7d0f85-df0e-425f-a2c4-b8952f42b7ac', 'tags': ['seq:step:1'], 'metadata': {}, 'data': {'chunk': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')], 'next': None}}}
# {'event': 'on_chain_end', 'name': 'RunnableLambda', 'run_id': 'da7d0f85-df0e-425f-a2c4-b8952f42b7ac', 'tags': ['seq:step:1'], 'metadata': {}, 'data': {'input': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')], 'next': None}, 'output': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')], 'next': None}}}
# {'event': 'on_prompt_start', 'name': 'ChatPromptTemplate', 'run_id': '9019cb79-5eea-41c1-aa40-a57a99f21953', 'tags': ['seq:step:2'], 'metadata': {}, 'data': {'input': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')], 'next': None}}}
# {'event': 'on_prompt_end', 'name': 'ChatPromptTemplate', 'run_id': '9019cb79-5eea-41c1-aa40-a57a99f21953', 'tags': ['seq:step:2'], 'metadata': {}, 'data': {'input': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')], 'next': None}, 'output': None}}
# {'event': 'on_chain_end', 'name': 'supervisor', 'run_id': 'ac964d7c-f88e-4b49-8b43-dfda62cdf77b', 'tags': ['graph:step:2'], 'metadata': {}, 'data': {'input': {'initial_query': 'What is 576 * 5 / 13?', 'messages': [HumanMessage(content='What is 576 * 5 / 13?')], 'next': None}, 'output': None}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[462], line 2
#       1 messages = [HumanMessage(content="What is 576 * 5 / 13?")]
# ----> 2 async for event in app.astream_events(
#       3     {
#       4         'initial_query': messages[0].content,
#       5         "messages": messages
#       6     },
#       7     {"recursion_limit": 100},
#       8     version="v1"
#       9 ):
#      10     kind = event["event"]
#      11     print(event)
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:889, in Runnable.astream_events(self, input, config, version, include_names, include_types, include_tags, exclude_names, exclude_types, exclude_tags, **kwargs)
#     885 root_name = config.get("run_name", self.get_name())
#     887 # Ignoring mypy complaint about too many different union combinations
#     888 # This arises because many of the argument types are unions
# --> 889 async for log in _astream_log_implementation(  # type: ignore[misc]
#     890     self,
#     891     input,
#     892     config=config,
#     893     stream=stream,
#     894     diff=True,
#     895     with_streamed_output_list=True,
#     896     **kwargs,
#     897 ):
#     898     run_log = run_log + log
#     900     if not encountered_start_event:
#     901         # Yield the start event for the root runnable.
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/tracers/log_stream.py:612, in _astream_log_implementation(runnable, input, config, stream, diff, with_streamed_output_list, **kwargs)
#     609 finally:
#     610     # Wait for the runnable to finish, if not cancelled (eg. by break)
#     611     try:
# --> 612         await task
#     613     except asyncio.CancelledError:
#     614         pass
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/tracers/log_stream.py:566, in _astream_log_implementation.<locals>.consume_astream()
#     563 prev_final_output: Optional[Output] = None
#     564 final_output: Optional[Output] = None
# --> 566 async for chunk in runnable.astream(input, config, **kwargs):
#     567     prev_final_output = final_output
#     568     if final_output is None:
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langgraph/pregel/__init__.py:657, in Pregel.astream(self, input, config, output_keys, input_keys, **kwargs)
#     654 async def input_stream() -> AsyncIterator[Union[dict[str, Any], Any]]:
#     655     yield input
# --> 657 async for chunk in self.atransform(
#     658     input_stream(),
#     659     config,
#     660     output_keys=output_keys,
#     661     input_keys=input_keys,
#     662     **kwargs,
#     663 ):
#     664     yield chunk
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langgraph/pregel/__init__.py:675, in Pregel.atransform(self, input, config, output_keys, input_keys, **kwargs)
#     666 async def atransform(
#     667     self,
#     668     input: AsyncIterator[Union[dict[str, Any], Any]],
#    (...)
#     673     **kwargs: Any,
#     674 ) -> AsyncIterator[Union[dict[str, Any], Any]]:
# --> 675     async for chunk in self._atransform_stream_with_config(
#     676         input,
#     677         self._atransform,
#     678         config,
#     679         output_keys=output_keys,
#     680         input_keys=input_keys,
#     681         **kwargs,
#     682     ):
#     683         yield chunk
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:1595, in Runnable._atransform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    1593 while True:
#    1594     if accepts_context(asyncio.create_task):
# -> 1595         chunk: Output = await asyncio.create_task(  # type: ignore[call-arg]
#    1596             py_anext(iterator),  # type: ignore[arg-type]
#    1597             context=context,
#    1598         )
#    1599     else:
#    1600         chunk = cast(Output, await py_anext(iterator))
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/tracers/log_stream.py:237, in LogStreamCallbackHandler.tap_output_aiter(self, run_id, output)
#     233 async def tap_output_aiter(
#     234     self, run_id: UUID, output: AsyncIterator[T]
#     235 ) -> AsyncIterator[T]:
#     236     """Tap an output async iterator to stream its values to the log."""
# --> 237     async for chunk in output:
#     238         # root run is handled in .astream_log()
#     239         if run_id != self.root_id:
#     240             # if we can't find the run silently ignore
#     241             # eg. because this run wasn't included in the log
#     242             if key := self._key_map_by_run_id.get(run_id):
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langgraph/pregel/__init__.py:524, in Pregel._atransform(self, input, run_manager, config, input_keys, output_keys, interrupt)
#     517 done, inflight = await asyncio.wait(
#     518     futures,
#     519     return_when=asyncio.FIRST_EXCEPTION,
#     520     timeout=self.step_timeout,
#     521 )
#     523 # interrupt on failure or timeout
# --> 524 _interrupt_or_proceed(done, inflight, step)
#     526 # apply writes to channels
#     527 _apply_writes(
#     528     checkpoint, channels, pending_writes, config, step + 1
#     529 )
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langgraph/pregel/__init__.py:698, in _interrupt_or_proceed(done, inflight, step)
#     696             inflight.pop().cancel()
#     697         # raise the exception
# --> 698         raise exc
#     699         # TODO this is where retry of an entire step would happen
#     701 if inflight:
#     702     # if we got here means we timed out
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langgraph/pregel/__init__.py:836, in _aconsume(iterator)
#     834 async def _aconsume(iterator: AsyncIterator[Any]) -> None:
#     835     """Consume an async iterator."""
# --> 836     async for _ in iterator:
#     837         pass
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:4144, in RunnableBindingBase.astream(self, input, config, **kwargs)
#    4138 async def astream(
#    4139     self,
#    4140     input: Input,
#    4141     config: Optional[RunnableConfig] = None,
#    4142     **kwargs: Optional[Any],
#    4143 ) -> AsyncIterator[Output]:
# -> 4144     async for item in self.bound.astream(
#    4145         input,
#    4146         self._merge_configs(config),
#    4147         **{**self.kwargs, **kwargs},
#    4148     ):
#    4149         yield item
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:2449, in RunnableSequence.astream(self, input, config, **kwargs)
#    2446 async def input_aiter() -> AsyncIterator[Input]:
#    2447     yield input
# -> 2449 async for chunk in self.atransform(input_aiter(), config, **kwargs):
#    2450     yield chunk
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:2432, in RunnableSequence.atransform(self, input, config, **kwargs)
#    2426 async def atransform(
#    2427     self,
#    2428     input: AsyncIterator[Input],
#    2429     config: Optional[RunnableConfig] = None,
#    2430     **kwargs: Optional[Any],
#    2431 ) -> AsyncIterator[Output]:
# -> 2432     async for chunk in self._atransform_stream_with_config(
#    2433         input,
#    2434         self._atransform,
#    2435         patch_config(config, run_name=(config or {}).get("run_name") or self.name),
#    2436         **kwargs,
#    2437     ):
#    2438         yield chunk
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:1595, in Runnable._atransform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    1593 while True:
#    1594     if accepts_context(asyncio.create_task):
# -> 1595         chunk: Output = await asyncio.create_task(  # type: ignore[call-arg]
#    1596             py_anext(iterator),  # type: ignore[arg-type]
#    1597             context=context,
#    1598         )
#    1599     else:
#    1600         chunk = cast(Output, await py_anext(iterator))
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/tracers/log_stream.py:237, in LogStreamCallbackHandler.tap_output_aiter(self, run_id, output)
#     233 async def tap_output_aiter(
#     234     self, run_id: UUID, output: AsyncIterator[T]
#     235 ) -> AsyncIterator[T]:
#     236     """Tap an output async iterator to stream its values to the log."""
# --> 237     async for chunk in output:
#     238         # root run is handled in .astream_log()
#     239         if run_id != self.root_id:
#     240             # if we can't find the run silently ignore
#     241             # eg. because this run wasn't included in the log
#     242             if key := self._key_map_by_run_id.get(run_id):
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:2402, in RunnableSequence._atransform(self, input, run_manager, config)
#    2394 for step in steps:
#    2395     final_pipeline = step.atransform(
#    2396         final_pipeline,
#    2397         patch_config(
#    (...)
#    2400         ),
#    2401     )
# -> 2402 async for output in final_pipeline:
#    2403     yield output
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/passthrough.py:269, in RunnablePassthrough.atransform(self, input, config, **kwargs)
#     266 else:
#     267     final = None
# --> 269     async for chunk in self._atransform_stream_with_config(
#     270         input, identity, config
#     271     ):
#     272         yield chunk
#     273         if final is None:
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:1560, in Runnable._atransform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    1558 input_for_tracing, input_for_transform = atee(input, 2)
#    1559 # Start the input iterator to ensure the input runnable starts before this one
# -> 1560 final_input: Optional[Input] = await py_anext(input_for_tracing, None)
#    1561 final_input_supported = True
#    1562 final_output: Optional[Output] = None
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/utils/aiter.py:62, in py_anext.<locals>.anext_impl()
#      55 async def anext_impl() -> Union[T, Any]:
#      56     try:
#      57         # The C code is way more low-level than this, as it implements
#      58         # all methods of the iterator protocol. In this implementation
#      59         # we're relying on higher-level coroutine concepts, but that's
#      60         # exactly what we want -- crosstest pure-Python high-level
#      61         # implementation and low-level C anext() iterators.
# ---> 62         return await __anext__(iterator)
#      63     except StopAsyncIteration:
#      64         return default
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/utils/aiter.py:97, in tee_peer(iterator, buffer, peers, lock)
#      95     continue
#      96 try:
# ---> 97     item = await iterator.__anext__()
#      98 except StopAsyncIteration:
#      99     break
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/output_parsers/transform.py:60, in BaseTransformOutputParser.atransform(self, input, config, **kwargs)
#      54 async def atransform(
#      55     self,
#      56     input: AsyncIterator[Union[str, BaseMessage]],
#      57     config: Optional[RunnableConfig] = None,
#      58     **kwargs: Any,
#      59 ) -> AsyncIterator[T]:
# ---> 60     async for chunk in self._atransform_stream_with_config(
#      61         input, self._atransform, config, run_type="parser"
#      62     ):
#      63         yield chunk
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:1560, in Runnable._atransform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    1558 input_for_tracing, input_for_transform = atee(input, 2)
#    1559 # Start the input iterator to ensure the input runnable starts before this one
# -> 1560 final_input: Optional[Input] = await py_anext(input_for_tracing, None)
#    1561 final_input_supported = True
#    1562 final_output: Optional[Output] = None
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/utils/aiter.py:62, in py_anext.<locals>.anext_impl()
#      55 async def anext_impl() -> Union[T, Any]:
#      56     try:
#      57         # The C code is way more low-level than this, as it implements
#      58         # all methods of the iterator protocol. In this implementation
#      59         # we're relying on higher-level coroutine concepts, but that's
#      60         # exactly what we want -- crosstest pure-Python high-level
#      61         # implementation and low-level C anext() iterators.
# ---> 62         return await __anext__(iterator)
#      63     except StopAsyncIteration:
#      64         return default
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/utils/aiter.py:97, in tee_peer(iterator, buffer, peers, lock)
#      95     continue
#      96 try:
# ---> 97     item = await iterator.__anext__()
#      98 except StopAsyncIteration:
#      99     break
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:1061, in Runnable.atransform(self, input, config, **kwargs)
#    1058 final: Input
#    1059 got_first_val = False
# -> 1061 async for chunk in input:
#    1062     if not got_first_val:
#    1063         final = chunk
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:1071, in Runnable.atransform(self, input, config, **kwargs)
#    1068         final = final + chunk  # type: ignore[operator]
#    1070 if got_first_val:
# -> 1071     async for output in self.astream(final, config, **kwargs):
#    1072         yield output
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:592, in Runnable.astream(self, input, config, **kwargs)
#     582 async def astream(
#     583     self,
#     584     input: Input,
#     585     config: Optional[RunnableConfig] = None,
#     586     **kwargs: Optional[Any],
#     587 ) -> AsyncIterator[Output]:
#     588     """
#     589     Default implementation of astream, which calls ainvoke.
#     590     Subclasses should override this method if they support streaming output.
#     591     """
# --> 592     yield await self.ainvoke(input, config, **kwargs)
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:498, in Runnable.ainvoke(self, input, config, **kwargs)
#     488 async def ainvoke(
#     489     self, input: Input, config: Optional[RunnableConfig] = None, **kwargs: Any
#     490 ) -> Output:
#     491     """Default implementation of ainvoke, calls invoke from a thread.
#     492
#     493     The default implementation allows usage of async code even if
#    (...)
#     496     Subclasses should override this method if they can run asynchronously.
#     497     """
# --> 498     return await run_in_executor(config, self.invoke, input, config, **kwargs)
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/config.py:493, in run_in_executor(executor_or_config, func, *args, **kwargs)
#     480 """Run a function in an executor.
#     481
#     482 Args:
#    (...)
#     489     Output: The output of the function.
#     490 """
#     491 if executor_or_config is None or isinstance(executor_or_config, dict):
#     492     # Use default executor with context copied from current context
# --> 493     return await asyncio.get_running_loop().run_in_executor(
#     494         None,
#     495         cast(Callable[..., T], partial(copy_context().run, func, *args, **kwargs)),
#     496     )
#     498 return await asyncio.get_running_loop().run_in_executor(
#     499     executor_or_config, partial(func, **kwargs), *args
#     500 )
#
# File /usr/lib/python3.11/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/prompts/base.py:112, in BasePromptTemplate.invoke(self, input, config)
#     110 if self.tags:
#     111     config["tags"].extend(self.tags)
# --> 112 return self._call_with_config(
#     113     self._format_prompt_with_error_handling,
#     114     input,
#     115     config,
#     116     run_type="prompt",
#     117 )
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/base.py:1246, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#    1242     context = copy_context()
#    1243     context.run(var_child_runnable_config.set, child_config)
#    1244     output = cast(
#    1245         Output,
# -> 1246         context.run(
#    1247             call_func_with_variable_args,
#    1248             func,  # type: ignore[arg-type]
#    1249             input,  # type: ignore[arg-type]
#    1250             config,
#    1251             run_manager,
#    1252             **kwargs,
#    1253         ),
#    1254     )
#    1255 except BaseException as e:
#    1256     run_manager.on_chain_error(e)
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/runnables/config.py:326, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     324 if run_manager is not None and accepts_run_manager(func):
#     325     kwargs["run_manager"] = run_manager
# --> 326 return func(input, **kwargs)
#
# File /home/dev/master-thesis/src/langchain/langchain-env/lib/python3.11/site-packages/langchain_core/prompts/base.py:97, in BasePromptTemplate._format_prompt_with_error_handling(self, inner_input)
#      95 missing = set(self.input_variables).difference(inner_input)
#      96 if missing:
# ---> 97     raise KeyError(
#      98         f"Input to {self.__class__.__name__} is missing variables {missing}. "
#      99         f" Expected: {self.input_variables}"
#     100         f" Received: {list(inner_input.keys())}"
#     101     )
#     102 return self.format_prompt(**inner_input)
#
# KeyError: 'Input to ChatPromptTemplate is missing variables {"\'next\'"}.  Expected: ["\'next\'", \'initial_query\', \'messages\'] Received: [\'initial_query\', \'messages\', \'next\']'

# %%
# initial_msg = "What is 576 * 5 / 13?"

# async for s in app.astream(
#     {
#         'initial_query': initial_msg,
#         "messages": [HumanMessage(
#         content=initial_msg)]},
#     {"recursion_limit": 100},
# ):
#     print(s)
#     # if "__end__" not in s:
#     #     print(s)
#     #     print("----")
