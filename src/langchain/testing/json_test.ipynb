# %%
data = """[{'jsonb_build_object': {'type': 'FeatureCollection', 'features': [{'id': 2, 'type': 'Feature', 'geometry': {'type': 'Polygon', 'coordinates': [[[10.291700351, 63.308942628], [10.291432789, 63.308990315], [10.29170142, 63.308946488], [10.291700351, 63.308942628]]]}, 'properties': {'gml_id': 'id52c7aee1-3a95-4574-afe4-690a10e750f6', 'opphav': "'Statens vegvesen, beregnet med grunnlagsdata fra fkb-kartlegging og NVDB-data' ", 'kommune': 5028, 'lokalId': 'b66ab140-946f-4e26-bb4b-c871d40f9229', 'navnerom': 'http://data.geonorge.no/sosi/forurensning/stoykartlegging_veg.xsd', 'versjonId': 20190101, 'st├©ykilde': 'V', 'beregnet├àr': 2035, 'm├Ñlemetode': 69, 'st├©ymetode': "'Norst├©y versjon 3, beregningsmetode Nord2000' ", 'datafangstdato': '2017-06-15', 'datauttaksdato': '2022-02-08T16:18:49', 'st├©ykildenavn': 'ERF-veger', 'st├©ysonekategori': 'R'}}, {'id': 3, 'type': 'Feature', 'geometry': {'type': 'Polygon', 'coordinates': [[[10.268899081, 63.322393392], [10.269068338, 63.322323891], [10.269067247, 63.322323855], [10.268997594, 63.322352658], [10.268899081, 63.322393392]]]}, 'properties': {'gml_id': 'idc2dae70e-cfdc-4350-b918-e350215ed35f', 'opphav': "'Statens vegvesen, beregnet med grunnlagsdata fra fkb-kartlegging og NVDB-data' ", 'kommune': 5028, 'lokalId': '3d330b6a-d94f-4214-a857-280d4be18c2d', 'navnerom': 'http://data.geonorge.no/sosi/forurensning/stoykartlegging_veg.xsd', 'versjonId': 20190101, 'st├©ykilde': 'V', 'beregnet├àr': 2035, 'm├Ñlemetode': 69, 'st├©ymetode': "'Norst├©y versjon 3, beregningsmetode Nord2000' ", 'datafangstdato': '2017-06-15', 'datauttaksdato': '2022-02-08T16:18:49', 'st├©ykildenavn': 'ERF-veger', 'st├©ysonekategori': 'R'}}, {'id': 4, 'type': 'Feature', 'geometry': {'type': 'Polygon', 'coordinates': [[[10.362567498, 63.317064758], [10.362413668, 63.317102962], [10.362381337, 63.317164586], [10.362379864, 63.317167372], [10.362422247, 63.317105578], [10.362568712, 63.317065389], [10.362567498, 63.317064758]]]}, 'properties': {'gml_id': 'id499e91c3-32f7-4e59-8d44-8cfbfa99160c', 'opphav': "'Statens vegvesen, beregnet med grunnlagsdata fra fkb-kartlegging og NVDB-data' ", 'kommune': 5028, 'lokalId': 'a2685f86-2eb7-4a4d-a49f-4dc15f35405d', 'navnerom': 'http://data.geonorge.no/sosi/forurensning/stoykartlegging_veg.xsd',
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'versjonId': 20190101, 'st├©ykilde': 'V', 'beregnet├àr': 2035, 'm├Ñlemetode': 69, 'st├©ymetode': "'Norst├©y versjon 3, beregningsmetode Nord2000' ", 'datafangstdato': '2017-06-15', 'datauttaksdato': '2022-02-08T16:18:49', 'st├©ykildenavn': 'ERF-veger', 'st├©ysonekategori': 'R'}}, {'id': 5, 'type': 'Feature', 'geometry': {'type': 'Polygon', 'coordinates': [[[10.362299385, 63.317352013], [10.362302297, 63.317353459], [10.362315286, 63.317311687], [10.362299385, 63.317352013]]]}, 'properties': {'gml_id': 'id667fd945-76a0-43ff-9294-85fd766d12d3', 'opphav': "'Statens vegvesen, beregnet med grunnlagsdata fra fkb-kartlegging og NVDB-data' ", 'kommune': 5028, 'lokalId': 'a2685f86-2eb7-4a4d-a49f-4dc15f35405d', 'navnerom': 'http://data.geonorge.no/sosi/forurensning/stoykartlegging_veg.xsd', 'versjonId': 20190101, 'st├©ykilde': 'V', 'beregnet├àr': 2035, 'm├Ñlemetode': 69, 'st├©ymetode': "'Norst├©y versjon 3, beregningsmetode Nord2000' ", 'datafangstdato': '2017-06-15', 'datauttaksdato': '2022-02-08T16:18:49', 'st├©ykildenavn': 'ERF-veger', 'st├©ysonekategori': 'R'}}, {'id': 1, 'type': 'Feature', 'geometry': {'type': 'Polygon', 'coordinates': [[[10.293725146, 63.312803853], [10.293863604, 63.313007877], [10.294009053, 63.313217729], [10.294156455, 63.313426656], [10.294299148, 63.31363138], [10.294510899, 63.313942077], [10.29466575, 63.314158084], [10.29480617, 63.31436696], [10.294956275, 63.314577773], [10.295094275, 63.314779464], [10.295264192, 63.315014674], [10.295136147, 63.315033372], [10.295096588, 63.315039258], [10.294311846, 63.315154316], [10.294099629, 63.315185441], [10.294100073, 63.31518607], [10.295267474, 63.315017838], [10.293725146, 63.312803853]]]}, 'properties': {'gml_id': 'id782db208-6f16-449b-b250-18e4665ada9d', 'opphav': "'Statens vegvesen, beregnet med grunnlagsdata fra fkb-kartlegging og NVDB-data' ", 'kommune': 5028, 'lokalId': 'b66ab140-946f-4e26-bb4b-c871d40f9229', 'navnerom': 'http://data.geonorge.no/sosi/forurensning/stoykartlegging_veg.xsd', 'versjonId': 20190101, 'st├©ykilde': 'V', 'beregnet├àr': 2035, 'm├Ñlemetode': 69, 'st├©ymetode': "'Norst├©y versjon 3, beregningsmetode Nord2000' ", 'datafangstdato': '2017-06-15', 'datauttaksdato': '2022-02-08T16:18:49', 'st├©ykildenavn': 'ERF-veger', 'st├©ysonekategori': 'R'}}]}}]"""
data
# Out:
# '[{\'jsonb_build_object\': {\'type\': \'FeatureCollection\', \'features\': [{\'id\': 2, \'type\': \'Feature\', \'geometry\': {\'type\': \'Polygon\', \'coordinates\': [[[10.291700351, 63.308942628], [10.291432789, 63.308990315], [10.29170142, 63.308946488], [10.291700351, 63.308942628]]]}, \'properties\': {\'gml_id\': \'id52c7aee1-3a95-4574-afe4-690a10e750f6\', \'opphav\': "\'Statens vegvesen, beregnet med grunnlagsdata fra fkb-kartlegging og NVDB-data\' ", \'kommune\': 5028, \'lokalId\': \'b66ab140-946f-4e26-bb4b-c871d40f9229\', \'navnerom\': \'http://data.geonorge.no/sosi/forurensning/stoykartlegging_veg.xsd\', \'versjonId\': 20190101, \'st├©ykilde\': \'V\', \'beregnet├àr\': 2035, \'m├Ñlemetode\': 69, \'st├©ymetode\': "\'Norst├©y versjon 3, beregningsmetode Nord2000\' ", \'datafangstdato\': \'2017-06-15\', \'datauttaksdato\': \'2022-02-08T16:18:49\', \'st├©ykildenavn\': \'ERF-veger\', \'st├©ysonekategori\': \'R\'}}, {\'id\': 3, \'type\': \'Feature\', \'geometry\': {\'type\': \'Polyg
# ...

# %%
import json

d = """{'a': 'b'}"""

json.loads(d)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[3], line 5
#       1 import json
#       3 d = """{'a': 'b'}"""
# ----> 5 json.loads(d)
#
# File /usr/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /usr/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
# ...

# %%
str({"result": [{"value": "the quick"}, {"value": " lazy fox"}]})
# Out:
# "{'result': [{'value': 'the quick'}, {'value': ' lazy fox'}]}"

# %%
import json

# Replace '../output.geojson' with the actual path to your file
file_path = '../output.geojson'

with open(file_path, 'r') as file:
    # Load the JSON content
    data = json.load(file)

    # Print the JSON content with indentation for better readability
    # Here, indent=4 specifies 4 spaces for indentation
    print(json.dumps(data, indent=4))
# Out:
# {
#     "type": "FeatureCollection",
#     "features": [
#         {
#             "id": 2,
#             "type": "Feature",
#             "geometry": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             10.291700351,
#                             63.308942628
#                         ],
#                         [
#                             10.291432789,
#                             63.308990315
#                         ],
#                         [
#                             10.29170142,
#                             63.308946488
#                         ],
#                         [
#                             10.291700351,
#                             63.308942628
#                         ]
#                     ]
#                 ]
#             },
#             "properties": {
#                 "gml_id": "id52c7aee1-3a95-4574-afe4-690a10e750f6",
# ...
